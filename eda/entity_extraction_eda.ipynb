# %%
# %pip install -r ../ner_app/requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spacy

email_path = 'data/emails/sync_emails.csv'
nlp = spacy.load('en_core_web_sm')

df = pd.read_csv(email_path)
print(df.head())
# Out:
# /Users/lukewescott/Documents/dev_link/blu-turtle/blume/venv/lib/python3.14/site-packages/confection/__init__.py:38: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel, Extra, ValidationError, create_model
# ---------------------------------------------------------------------------
# ConfigError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import spacy
#       7 email_path = 'data/emails/sync_emails.csv'
#       8 nlp = spacy.load('en_core_web_sm')
#
# File ~/Documents/dev_link/blu-turtle/blume/venv/lib/python3.14/site-packages/spacy/__init__.py:13
#      10 # These are imported as part of the API
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
# ---> 13 from . import pipeline  # noqa: F401
#      14 from . import util
# ...

# %%
# print(df.info())
# print(df.describe())

# %%
# df['text_length'] = df['text_column'].apply(len)
# df['word_count'] = df['text_column'].apply(lambda x: len(x.split()))

# sns.histplot(df['text_length'])
# plt.show()

# sns.histplot(df['word_count'])
# plt.show()

# %% [markdown]
# ## NER stuff

# %%
# Load a pre-trained NER model from spaCy
# nlp = spacy.load('en_core_web_sm')

# def extract_entities(text):
#     doc = nlp(text)
#     return [(ent.text, ent.label_) for ent in doc.ents]

# df['entities'] = df['text_column'].apply(extract_entities)
# print(df.head())

# %% [markdown]
# ## 5. Entity Frequency Analysis

# %%
# all_entities = [entity for entities_list in df['entities'] for entity in entities_list]
# entity_counts = pd.DataFrame(all_entities, columns=['entity', 'label']).value_counts()

# print(entity_counts.head(20))

# %% [markdown]
# ## 6. Visualize Entity Distribution

# %%
# plt.figure(figsize=(12, 8))
# sns.countplot(y=[label for _, label in all_entities], order=[label for label, count in entity_counts.head(20).items()])
# plt.title('Top 20 Entity Labels')
# plt.show()
